# %%
df = spark.table("samples.nyctaxi.trips")
df.display()

# %%
# %sql
show catalogs

# %%
# %sql
-- Create schemas for Medallion Architecture in the workspace catalog
CREATE SCHEMA IF NOT EXISTS workspace.bronze

# %%
df.write.mode("overwrite").saveAsTable("bronze.bronze_raw")
